# %%
import matplotlib.pyplot as plt
import numpy as np

# Значения λ и соответствующие значения средней нагрузки R̄
lambda_vals = np.array([0.5, 1, 2, 3, 4, 5, 6, 6.5, 7, 7.5, 8, 10, 15, 20])
R_bar_vals = np.array([1, 2, 4.5, 8, 13, 18, 25, 32, 40, 46, 49, 50, 50, 50])

# Задержка
w_r_vals = R_bar_vals / lambda_vals

# Оценка критической точки перегрузки (максимум задержки)
max_index = np.argmax(w_r_vals)
lambda_crit = lambda_vals[max_index]
w_r_crit = w_r_vals[max_index]

# Построение графика
import matplotlib.pyplot as plt
import numpy as np
lambda_vals = np.array([0.5, 1, 2, 3, 4, 5, 6, 6.5, 7, 7.5, 8, 10, 15, 20])
R_bar_vals = np.array([1, 2, 4.5, 8, 13, 18, 25, 32, 40, 46, 49, 50, 50, 50])


w_r_vals = R_bar_vals / lambda_vals

max_index = np.argmax(w_r_vals)
lambda_crit = lambda_vals[max_index]
w_r_crit = w_r_vals[max_index]

plt.figure(figsize=(10, 6))
plt.plot(lambda_vals, w_r_vals, marker='o', color='orange', label='Задержка $w_r = \\bar{R}/\\lambda$')
plt.title("Зависимость средней задержки $w_r$ от интенсивности потока заявок $\\lambda$")
plt.xlabel("Интенсивность потока заявок λ")
plt.ylabel("Средняя задержка $w_r$")
plt.grid(True)
plt.legend()
